# %%
import simpy
import random

# %%
CUSTOMER_NUM=100
INTERVAL_CUSTOMERS=3.0 #average customer arrival interval
MIN_WAITTIME=2.0
MAX_WAITTIME=5.0
MIN_ORDERTIME=1.0
MAX_ORDERTIME=3.0
menu = {"latte":3.0,"cappuccino":3.0,"americano":1.5,"mocha":3.5,"Caramel Macchiato":4.0}

# %%
#Source generates customers randomly
def source(env,number,interval,counter):
    for i in range(number):
        c = customer(env,i,counter)
        env.process(c)
        t=random.expovariate(1.0/interval)
        yield env.timeout(t)

# %%
#customers activities: arrive, order, wait for the cafe and leave
def customer(env,name,counter):
    #customer arrives in the cafe
    arrive=env.now
    print("Minute%4.2f---Customer%d arrives at the cafe."%(arrive,name) )
    
    with counter.request() as req:
        wait_time= random.uniform(MIN_WAITTIME,MAX_WAITTIME)
        results= yield req | env.timeout(wait_time)
        
        wait=env.now-arrive
        
        if req in results:
            print("Minute%4.2f---Customer%d starts to order."%(env.now,name))
            order_time=random.uniform(MIN_ORDERTIME,MAX_ORDERTIME)
            yield env.timeout(order_time)
            caffee_type=random.choice(list(menu))
            print("Minute%4.2f---Customer%d order a %s."%(env.now,name,caffee_type))
            making_time=menu[caffee_type]
            yield env.timeout(making_time)
            print("Minute%4.2f---Customer%d get the %s and leave."%(env.now,name, caffee_type))
        
        else:
            print("Minute%4.2f---Customer%d leaves the cafe after waiting for %2.1f minutes."%(env.now,name,wait))

# %%
#open 1 counter
#start the simulation 
print("Cafe simulation starts")
print("-----------------------------------------------------------")
env=simpy.Environment()

counter=simpy.Resource(env,capacity=1)
env.process(source(env,CUSTOMER_NUM,INTERVAL_CUSTOMERS,counter))
env.run()
# Out:
# Cafe simulation starts
# -----------------------------------------------------------
# Minute0.00---Customer0 arrives at the cafe.
# Minute0.00---Customer0 starts to order.
# Minute1.93---Customer0 order a cappuccino.
# Minute3.93---Customer0 get the cappuccino and leave.
# Minute4.69---Customer1 arrives at the cafe.
# Minute4.69---Customer1 starts to order.
# Minute5.06---Customer2 arrives at the cafe.
# Minute5.77---Customer1 order a Caramel Macchiato.
# Minute6.46---Customer3 arrives at the cafe.
# Minute9.77---Customer1 get the Caramel Macchiato and leave.
# Minute9.77---Customer2 starts to order.
# Minute9.79---Customer4 arrives at the cafe.
# Minute9.94---Customer3 leaves the cafe after waiting for 3.5 minutes.
# Minute10.93---Customer2 order a americano.
# Minute12.43---Customer2 get the americano and leave.
# Minute12.43---Customer4 starts to order.
# Minute14.56---Customer4 order a cappuccino.
# Minute14.62---Customer5 arrives at the cafe.
# Minute15.11---Customer6 arrives at the cafe.
# Minute16.56---Customer4 get the cappuccino and leave.
# Minute16.56---Customer5 starts to order.
# Minute18.09---Customer5 order a cappuccino.
# Minute20.09---Customer5 get the cappuccino and leave.
# Minute20.09---Customer6 starts to order.
# Minute23.06---Customer6 order a cappuccino.
# Minute23.72---Customer7 arrives at the cafe.
# Minute25.06---Customer6 get the cappuccino and leave.
# Minute25.06---Customer7 starts to order.
# Minute25.77---Customer8 arrives at the cafe.
# Minute27.05---Customer7 order a Caramel Macchiato.
# Minute27.23---Customer9 arrives at the cafe.
# Minute30.85---Customer8 leaves the cafe after waiting for 5.1 minutes.
# Minute30.98---Customer9 leaves the cafe after waiting for 3.7 minutes.
# Minute31.05---Customer7 get the Caramel Macchiato and leave.
# Minute33.50---Customer10 arrives at the cafe.
# Minute33.50---Customer10 starts to order.
# Minute36.49---Customer10 order a americano.
# Minute37.99---Customer10 get the americano and leave.
# Minute42.10---Customer11 arrives at the cafe.
# Minute42.10---Customer11 starts to order.
# Minute42.35---Customer12 arrives at the cafe.
# Minute43.09---Customer13 arrives at the cafe.
# Minute43.84---Customer14 arrives at the cafe.
# Minute44.22---Customer11 order a Caramel Macchiato.
# Minute45.05---Customer12 leaves the cafe after waiting for 2.7 minutes.
# Minute45.34---Customer15 arrives at the cafe.
# Minute46.20---Customer16 arrives at the cafe.
# Minute47.80---Customer15 leaves the cafe after waiting for 2.5 minutes.
# Minute48.22---Customer11 get the Caramel Macchiato and leave.
# Minute48.22---Customer13 starts to order.
# Minute48.97---Customer14 leaves the cafe after waiting for 5.1 minutes.
# Minute49.86---Customer13 order a mocha.
# Minute50.50---Customer16 leaves the cafe after waiting for 4.3 minutes.
# Minute51.31---Customer17 arrives at the cafe.
# Minute53.36---Customer13 get the mocha and leave.
# Minute53.36---Customer17 starts to order.
# Minute54.49---Customer17 order a americano.
# Minute55.99---Customer17 get the americano and leave.
# Minute56.18---Customer18 arrives at the cafe.
# Minute56.18---Customer18 starts to order.
# Minute58.88---Customer18 order a americano.
# Minute59.34---Customer19 arrives at the cafe.
# Minute60.38---Customer18 get the americano and leave.
# Minute60.38---Customer19 starts to order.
# Minute62.10---Customer19 order a cappuccino.
# Minute63.43---Customer20 arrives at the cafe.
# Minute64.10---Customer19 get the cappuccino and leave.
# Minute64.10---Customer20 starts to order.
# Minute65.30---Customer20 order a americano.
# Minute66.80---Customer20 get the americano and leave.
# Minute70.08---Customer21 arrives at the cafe.
# Minute70.08---Customer21 starts to order.
# Minute71.87---Customer22 arrives at the cafe.
# Minute72.09---Customer21 order a latte.
# Minute73.67---Customer23 arrives at the cafe.
# Minute74.81---Customer22 leaves the cafe after waiting for 2.9 minutes.
# Minute75.09---Customer21 get the latte and leave.
# Minute75.09---Customer23 starts to order.
# Minute77.83---Customer23 order a latte.
# Minute80.83---Customer23 get the latte and leave.
# Minute81.36---Customer24 arrives at the cafe.
# Minute81.36---Customer24 starts to order.
# Minute84.28---Customer24 order a Caramel Macchiato.
# Minute88.28---Customer24 get the Caramel Macchiato and leave.
# Minute89.39---Customer25 arrives at the cafe.
# Minute89.39---Customer25 starts to order.
# Minute92.35---Customer25 order a Caramel Macchiato.
# Minute96.35---Customer25 get the Caramel Macchiato and leave.
# Minute96.75---Customer26 arrives at the cafe.
# Minute96.75---Customer26 starts to order.
# Minute98.35---Customer27 arrives at the cafe.
# Minute98.76---Customer26 order a Caramel Macchiato.
# Minute101.98---Customer27 leaves the cafe after waiting for 3.6 minutes.
# Minute102.76---Customer26 get the Caramel Macchiato and leave.
# Minute104.20---Customer28 arrives at the cafe.
# Minute104.20---Customer28 starts to order.
# Minute106.10---Customer28 order a americano.
# Minute107.60---Customer28 get the americano and leave.
# Minute109.08---Customer29 arrives at the cafe.
# Minute109.08---Customer29 starts to order.
# Minute111.88---Customer29 order a americano.
# Minute113.38---Customer29 get the americano and leave.
# Minute114.84---Customer30 arrives at the cafe.
# Minute114.84---Customer30 starts to order.
# Minute116.64---Customer30 order a mocha.
# Minute120.14---Customer30 get the mocha and leave.
# Minute120.75---Customer31 arrives at the cafe.
# Minute120.75---Customer31 starts to order.
# Minute123.26---Customer31 order a americano.
# Minute124.76---Customer31 get the americano and leave.
# Minute126.48---Customer32 arrives at the cafe.
# Minute126.48---Customer32 starts to order.
# Minute127.21---Customer33 arrives at the cafe.
# Minute127.31---Customer34 arrives at the cafe.
# Minute127.82---Customer35 arrives at the cafe.
# Minute128.15---Customer32 order a latte.
# Minute129.70---Customer36 arrives at the cafe.
# Minute130.55---Customer34 leaves the cafe after waiting for 3.2 minutes.
# Minute131.15---Customer32 get the latte and leave.
# Minute131.15---Customer33 starts to order.
# Minute132.00---Customer35 leaves the cafe after waiting for 4.2 minutes.
# Minute133.16---Customer33 order a latte.
# Minute133.41---Customer36 leaves the cafe after waiting for 3.7 minutes.
# Minute135.23---Customer37 arrives at the cafe.
# Minute136.16---Customer33 get the latte and leave.
# Minute136.16---Customer37 starts to order.
# Minute137.21---Customer37 order a americano.
# Minute138.71---Customer37 get the americano and leave.
# Minute139.45---Customer38 arrives at the cafe.
# Minute139.45---Customer38 starts to order.
# Minute141.63---Customer38 order a mocha.
# Minute143.27---Customer39 arrives at the cafe.
# Minute143.86---Customer40 arrives at the cafe.
# Minute143.87---Customer41 arrives at the cafe.
# Minute145.13---Customer38 get the mocha and leave.
# Minute145.13---Customer39 starts to order.
# Minute146.64---Customer39 order a latte.
# Minute147.50---Customer40 leaves the cafe after waiting for 3.6 minutes.
# Minute147.76---Customer42 arrives at the cafe.
# Minute148.28---Customer43 arrives at the cafe.
# Minute148.66---Customer41 leaves the cafe after waiting for 4.8 minutes.
# Minute149.64---Customer39 get the latte and leave.
# Minute149.64---Customer42 starts to order.
# Minute150.42---Customer43 leaves the cafe after waiting for 2.1 minutes.
# Minute152.42---Customer42 order a mocha.
# Minute154.04---Customer44 arrives at the cafe.
# Minute155.78---Customer45 arrives at the cafe.
# Minute155.92---Customer42 get the mocha and leave.
# Minute155.92---Customer44 starts to order.
# Minute156.95---Customer44 order a cappuccino.
# Minute157.22---Customer46 arrives at the cafe.
# Minute157.53---Customer47 arrives at the cafe.
# Minute158.95---Customer44 get the cappuccino and leave.
# Minute158.95---Customer45 starts to order.
# Minute161.42---Customer47 leaves the cafe after waiting for 3.9 minutes.
# Minute161.80---Customer45 order a latte.
# Minute162.96---Customer46 leaves the cafe after waiting for 5.7 minutes.
# Minute164.80---Customer45 get the latte and leave.
# Minute172.79---Customer48 arrives at the cafe.
# Minute172.79---Customer48 starts to order.
# Minute173.58---Customer49 arrives at the cafe.
# Minute174.75---Customer48 order a latte.
# Minute177.42---Customer50 arrives at the cafe.
# Minute177.75---Customer48 get the latte and leave.
# Minute177.75---Customer49 starts to order.
# Minute178.83---Customer51 arrives at the cafe.
# Minute180.02---Customer49 order a mocha.
# Minute181.67---Customer50 leaves the cafe after waiting for 4.3 minutes.
# Minute182.14---Customer52 arrives at the cafe.
# Minute183.52---Customer49 get the mocha and leave.
# Minute183.52---Customer51 starts to order.
# Minute183.53---Customer53 arrives at the cafe.
# Minute184.39---Customer54 arrives at the cafe.
# Minute184.84---Customer51 order a cappuccino.
# Minute186.84---Customer51 get the cappuccino and leave.
# Minute186.84---Customer52 starts to order.
# Minute187.89---Customer54 leaves the cafe after waiting for 3.5 minutes.
# Minute188.18---Customer52 order a latte.
# Minute188.96---Customer55 arrives at the cafe.
# Minute189.17---Customer53 leaves the cafe after waiting for 5.6 minutes.
# Minute191.18---Customer52 get the latte and leave.
# Minute191.18---Customer55 starts to order.
# Minute192.05---Customer56 arrives at the cafe.
# Minute192.67---Customer57 arrives at the cafe.
# Minute193.10---Customer55 order a mocha.
# Minute195.49---Customer56 leaves the cafe after waiting for 3.4 minutes.
# Minute195.59---Customer57 leaves the cafe after waiting for 2.9 minutes.
# Minute196.60---Customer55 get the mocha and leave.
# Minute198.47---Customer58 arrives at the cafe.
# Minute198.47---Customer58 starts to order.
# Minute200.53---Customer58 order a americano.
# Minute201.09---Customer59 arrives at the cafe.
# Minute202.03---Customer58 get the americano and leave.
# Minute202.03---Customer59 starts to order.
# Minute203.17---Customer59 order a mocha.
# Minute204.59---Customer60 arrives at the cafe.
# Minute204.73---Customer61 arrives at the cafe.
# Minute205.31---Customer62 arrives at the cafe.
# Minute206.67---Customer59 get the mocha and leave.
# Minute206.67---Customer60 starts to order.
# Minute207.47---Customer62 leaves the cafe after waiting for 2.2 minutes.
# Minute208.14---Customer61 leaves the cafe after waiting for 3.4 minutes.
# Minute209.29---Customer60 order a latte.
# Minute209.67---Customer63 arrives at the cafe.
# Minute211.49---Customer64 arrives at the cafe.
# Minute212.22---Customer63 leaves the cafe after waiting for 2.6 minutes.
# Minute212.29---Customer60 get the latte and leave.
# Minute212.29---Customer64 starts to order.
# Minute212.89---Customer65 arrives at the cafe.
# Minute213.55---Customer64 order a latte.
# Minute214.06---Customer66 arrives at the cafe.
# Minute215.38---Customer67 arrives at the cafe.
# Minute215.80---Customer68 arrives at the cafe.
# Minute216.48---Customer65 leaves the cafe after waiting for 3.6 minutes.
# Minute216.55---Customer64 get the latte and leave.
# Minute216.55---Customer66 starts to order.
# Minute218.07---Customer68 leaves the cafe after waiting for 2.3 minutes.
# Minute218.23---Customer67 leaves the cafe after waiting for 2.8 minutes.
# Minute218.86---Customer66 order a Caramel Macchiato.
# Minute219.18---Customer69 arrives at the cafe.
# Minute219.84---Customer70 arrives at the cafe.
# Minute221.78---Customer71 arrives at the cafe.
# Minute222.35---Customer72 arrives at the cafe.
# Minute222.71---Customer69 leaves the cafe after waiting for 3.5 minutes.
# Minute222.86---Customer66 get the Caramel Macchiato and leave.
# Minute222.86---Customer70 starts to order.
# Minute224.47---Customer73 arrives at the cafe.
# Minute225.50---Customer70 order a mocha.
# Minute227.10---Customer71 leaves the cafe after waiting for 5.3 minutes.
# Minute227.87---Customer72 leaves the cafe after waiting for 5.5 minutes.
# Minute228.84---Customer73 leaves the cafe after waiting for 4.4 minutes.
# Minute229.00---Customer70 get the mocha and leave.
# Minute229.07---Customer74 arrives at the cafe.
# Minute229.07---Customer74 starts to order.
# Minute231.27---Customer75 arrives at the cafe.
# Minute231.65---Customer74 order a cappuccino.
# Minute232.17---Customer76 arrives at the cafe.
# Minute233.65---Customer74 get the cappuccino and leave.
# Minute233.65---Customer75 starts to order.
# Minute233.99---Customer77 arrives at the cafe.
# Minute235.37---Customer78 arrives at the cafe.
# Minute235.95---Customer79 arrives at the cafe.
# Minute236.14---Customer75 order a americano.
# Minute237.15---Customer76 leaves the cafe after waiting for 5.0 minutes.
# Minute237.64---Customer75 get the americano and leave.
# Minute237.64---Customer77 starts to order.
# Minute237.75---Customer80 arrives at the cafe.
# Minute238.63---Customer81 arrives at the cafe.
# Minute238.76---Customer78 leaves the cafe after waiting for 3.4 minutes.
# Minute239.00---Customer82 arrives at the cafe.
# Minute239.18---Customer79 leaves the cafe after waiting for 3.2 minutes.
# Minute239.92---Customer77 order a mocha.
# Minute240.29---Customer83 arrives at the cafe.
# Minute241.40---Customer81 leaves the cafe after waiting for 2.8 minutes.
# Minute241.52---Customer82 leaves the cafe after waiting for 2.5 minutes.
# Minute242.90---Customer80 leaves the cafe after waiting for 5.2 minutes.
# Minute243.12---Customer83 leaves the cafe after waiting for 2.8 minutes.
# Minute243.42---Customer77 get the mocha and leave.
# Minute249.16---Customer84 arrives at the cafe.
# Minute249.16---Customer84 starts to order.
# Minute251.63---Customer84 order a latte.
# Minute252.15---Customer85 arrives at the cafe.
# Minute254.60---Customer86 arrives at the cafe.
# Minute254.63---Customer84 get the latte and leave.
# Minute254.63---Customer85 starts to order.
# Minute256.14---Customer85 order a cappuccino.
# Minute256.68---Customer87 arrives at the cafe.
# Minute258.14---Customer85 get the cappuccino and leave.
# Minute258.14---Customer86 starts to order.
# Minute260.59---Customer88 arrives at the cafe.
# Minute260.80---Customer86 order a cappuccino.
# Minute262.45---Customer87 leaves the cafe after waiting for 5.8 minutes.
# Minute262.72---Customer88 leaves the cafe after waiting for 2.1 minutes.
# Minute262.77---Customer89 arrives at the cafe.
# Minute262.80---Customer86 get the cappuccino and leave.
# Minute262.80---Customer89 starts to order.
# Minute264.84---Customer89 order a Caramel Macchiato.
# Minute266.78---Customer90 arrives at the cafe.
# Minute268.84---Customer89 get the Caramel Macchiato and leave.
# Minute268.84---Customer90 starts to order.
# Minute271.52---Customer90 order a latte.
# Minute272.40---Customer91 arrives at the cafe.
# Minute274.52---Customer90 get the latte and leave.
# Minute274.52---Customer91 starts to order.
# Minute274.68---Customer92 arrives at the cafe.
# Minute277.11---Customer91 order a latte.
# Minute278.35---Customer93 arrives at the cafe.
# Minute279.77---Customer92 leaves the cafe after waiting for 5.1 minutes.
# Minute280.11---Customer91 get the latte and leave.
# Minute280.11---Customer93 starts to order.
# Minute282.52---Customer93 order a mocha.
# Minute284.75---Customer94 arrives at the cafe.
# Minute285.52---Customer95 arrives at the cafe.
# Minute286.02---Customer93 get the mocha and leave.
# Minute286.02---Customer94 starts to order.
# Minute287.26---Customer94 order a latte.
# Minute289.30---Customer96 arrives at the cafe.
# Minute289.39---Customer95 leaves the cafe after waiting for 3.9 minutes.
# Minute289.60---Customer97 arrives at the cafe.
# Minute290.15---Customer98 arrives at the cafe.
# Minute290.26---Customer94 get the latte and leave.
# Minute290.26---Customer96 starts to order.
# Minute292.47---Customer99 arrives at the cafe.
# Minute292.54---Customer98 leaves the cafe after waiting for 2.4 minutes.
# Minute292.64---Customer96 order a Caramel Macchiato.
# Minute294.84---Customer99 leaves the cafe after waiting for 2.4 minutes.
# Minute295.48---Customer97 leaves the cafe after waiting for 5.9 minutes.
# Minute296.64---Customer96 get the Caramel Macchiato and leave.

# %%
#open 2 counter
#start the simulation 
print("Cafe simulation starts")
print("-----------------------------------------------------------")
env=simpy.Environment()

counter=simpy.Resource(env,capacity=2)
env.process(source(env,CUSTOMER_NUM,INTERVAL_CUSTOMERS,counter))
env.run()
# Out:
# Cafe simulation starts
# -----------------------------------------------------------
# Minute0.00---Customer0 arrives at the cafe.
# Minute0.00---Customer0 starts to order.
# Minute2.15---Customer1 arrives at the cafe.
# Minute2.15---Customer1 starts to order.
# Minute2.90---Customer0 order a mocha.
# Minute3.91---Customer1 order a mocha.
# Minute5.88---Customer2 arrives at the cafe.
# Minute6.40---Customer0 get the mocha and leave.
# Minute6.40---Customer2 starts to order.
# Minute7.41---Customer1 get the mocha and leave.
# Minute9.13---Customer2 order a latte.
# Minute12.13---Customer2 get the latte and leave.
# Minute12.66---Customer3 arrives at the cafe.
# Minute12.66---Customer3 starts to order.
# Minute14.08---Customer3 order a mocha.
# Minute16.11---Customer4 arrives at the cafe.
# Minute16.11---Customer4 starts to order.
# Minute17.58---Customer3 get the mocha and leave.
# Minute18.82---Customer4 order a americano.
# Minute20.32---Customer4 get the americano and leave.
# Minute21.79---Customer5 arrives at the cafe.
# Minute21.79---Customer5 starts to order.
# Minute23.96---Customer5 order a latte.
# Minute26.56---Customer6 arrives at the cafe.
# Minute26.56---Customer6 starts to order.
# Minute26.96---Customer5 get the latte and leave.
# Minute28.15---Customer6 order a Caramel Macchiato.
# Minute29.53---Customer7 arrives at the cafe.
# Minute29.53---Customer7 starts to order.
# Minute29.57---Customer8 arrives at the cafe.
# Minute31.96---Customer9 arrives at the cafe.
# Minute32.15---Customer6 get the Caramel Macchiato and leave.
# Minute32.15---Customer8 starts to order.
# Minute32.37---Customer7 order a americano.
# Minute32.75---Customer10 arrives at the cafe.
# Minute33.19---Customer8 order a latte.
# Minute33.87---Customer7 get the americano and leave.
# Minute33.87---Customer9 starts to order.
# Minute35.11---Customer10 leaves the cafe after waiting for 2.4 minutes.
# Minute35.72---Customer9 order a latte.
# Minute36.19---Customer8 get the latte and leave.
# Minute36.96---Customer11 arrives at the cafe.
# Minute36.96---Customer11 starts to order.
# Minute38.57---Customer11 order a mocha.
# Minute38.72---Customer9 get the latte and leave.
# Minute38.76---Customer12 arrives at the cafe.
# Minute38.76---Customer12 starts to order.
# Minute40.15---Customer12 order a latte.
# Minute40.78---Customer13 arrives at the cafe.
# Minute41.40---Customer14 arrives at the cafe.
# Minute42.07---Customer11 get the mocha and leave.
# Minute42.07---Customer13 starts to order.
# Minute43.15---Customer12 get the latte and leave.
# Minute43.15---Customer14 starts to order.
# Minute44.99---Customer13 order a latte.
# Minute45.84---Customer14 order a cappuccino.
# Minute47.31---Customer15 arrives at the cafe.
# Minute47.99---Customer13 get the latte and leave.
# Minute47.99---Customer15 starts to order.
# Minute48.36---Customer16 arrives at the cafe.
# Minute48.84---Customer14 get the cappuccino and leave.
# Minute48.84---Customer16 starts to order.
# Minute50.09---Customer15 order a americano.
# Minute50.81---Customer16 order a americano.
# Minute51.59---Customer15 get the americano and leave.
# Minute52.31---Customer16 get the americano and leave.
# Minute61.90---Customer17 arrives at the cafe.
# Minute61.90---Customer17 starts to order.
# Minute64.86---Customer17 order a cappuccino.
# Minute66.76---Customer18 arrives at the cafe.
# Minute66.76---Customer18 starts to order.
# Minute66.86---Customer19 arrives at the cafe.
# Minute67.28---Customer20 arrives at the cafe.
# Minute67.82---Customer21 arrives at the cafe.
# Minute67.86---Customer17 get the cappuccino and leave.
# Minute67.86---Customer19 starts to order.
# Minute68.37---Customer18 order a latte.
# Minute69.00---Customer22 arrives at the cafe.
# Minute70.60---Customer19 order a cappuccino.
# Minute70.68---Customer20 leaves the cafe after waiting for 3.4 minutes.
# Minute70.82---Customer21 leaves the cafe after waiting for 3.0 minutes.
# Minute71.05---Customer22 leaves the cafe after waiting for 2.0 minutes.
# Minute71.37---Customer18 get the latte and leave.
# Minute72.33---Customer23 arrives at the cafe.
# Minute72.33---Customer23 starts to order.
# Minute73.60---Customer19 get the cappuccino and leave.
# Minute74.66---Customer23 order a mocha.
# Minute76.05---Customer24 arrives at the cafe.
# Minute76.05---Customer24 starts to order.
# Minute76.06---Customer25 arrives at the cafe.
# Minute77.77---Customer24 order a cappuccino.
# Minute78.16---Customer23 get the mocha and leave.
# Minute78.16---Customer25 starts to order.
# Minute79.30---Customer25 order a mocha.
# Minute80.77---Customer24 get the cappuccino and leave.
# Minute82.80---Customer25 get the mocha and leave.
# Minute84.72---Customer26 arrives at the cafe.
# Minute84.72---Customer26 starts to order.
# Minute85.85---Customer26 order a americano.
# Minute86.41---Customer27 arrives at the cafe.
# Minute86.41---Customer27 starts to order.
# Minute86.48---Customer28 arrives at the cafe.
# Minute87.15---Customer29 arrives at the cafe.
# Minute87.35---Customer26 get the americano and leave.
# Minute87.35---Customer28 starts to order.
# Minute88.77---Customer27 order a americano.
# Minute89.59---Customer28 order a Caramel Macchiato.
# Minute90.27---Customer27 get the americano and leave.
# Minute90.27---Customer29 starts to order.
# Minute91.44---Customer30 arrives at the cafe.
# Minute92.45---Customer29 order a mocha.
# Minute93.45---Customer31 arrives at the cafe.
# Minute93.59---Customer28 get the Caramel Macchiato and leave.
# Minute93.59---Customer30 starts to order.
# Minute94.63---Customer30 order a latte.
# Minute95.47---Customer31 leaves the cafe after waiting for 2.0 minutes.
# Minute95.95---Customer29 get the mocha and leave.
# Minute97.45---Customer32 arrives at the cafe.
# Minute97.45---Customer32 starts to order.
# Minute97.63---Customer30 get the latte and leave.
# Minute98.13---Customer33 arrives at the cafe.
# Minute98.13---Customer33 starts to order.
# Minute99.29---Customer32 order a Caramel Macchiato.
# Minute99.52---Customer34 arrives at the cafe.
# Minute99.78---Customer33 order a americano.
# Minute100.62---Customer35 arrives at the cafe.
# Minute101.28---Customer33 get the americano and leave.
# Minute101.28---Customer34 starts to order.
# Minute103.29---Customer32 get the Caramel Macchiato and leave.
# Minute103.29---Customer35 starts to order.
# Minute103.89---Customer34 order a mocha.
# Minute105.38---Customer35 order a mocha.
# Minute105.73---Customer36 arrives at the cafe.
# Minute107.39---Customer34 get the mocha and leave.
# Minute107.39---Customer36 starts to order.
# Minute108.88---Customer35 get the mocha and leave.
# Minute110.06---Customer36 order a cappuccino.
# Minute113.06---Customer36 get the cappuccino and leave.
# Minute118.68---Customer37 arrives at the cafe.
# Minute118.68---Customer37 starts to order.
# Minute118.86---Customer38 arrives at the cafe.
# Minute118.86---Customer38 starts to order.
# Minute119.52---Customer39 arrives at the cafe.
# Minute120.81---Customer37 order a Caramel Macchiato.
# Minute121.32---Customer38 order a cappuccino.
# Minute122.89---Customer39 leaves the cafe after waiting for 3.4 minutes.
# Minute124.32---Customer38 get the cappuccino and leave.
# Minute124.79---Customer40 arrives at the cafe.
# Minute124.79---Customer40 starts to order.
# Minute124.81---Customer37 get the Caramel Macchiato and leave.
# Minute126.60---Customer40 order a mocha.
# Minute127.46---Customer41 arrives at the cafe.
# Minute127.46---Customer41 starts to order.
# Minute129.45---Customer42 arrives at the cafe.
# Minute130.10---Customer40 get the mocha and leave.
# Minute130.10---Customer42 starts to order.
# Minute130.12---Customer41 order a cappuccino.
# Minute131.46---Customer42 order a mocha.
# Minute132.27---Customer43 arrives at the cafe.
# Minute133.12---Customer41 get the cappuccino and leave.
# Minute133.12---Customer43 starts to order.
# Minute134.31---Customer43 order a americano.
# Minute134.96---Customer42 get the mocha and leave.
# Minute135.81---Customer43 get the americano and leave.
# Minute136.49---Customer44 arrives at the cafe.
# Minute136.49---Customer44 starts to order.
# Minute138.12---Customer44 order a mocha.
# Minute140.45---Customer45 arrives at the cafe.
# Minute140.45---Customer45 starts to order.
# Minute141.62---Customer44 get the mocha and leave.
# Minute141.98---Customer46 arrives at the cafe.
# Minute141.98---Customer46 starts to order.
# Minute142.75---Customer45 order a cappuccino.
# Minute144.07---Customer46 order a Caramel Macchiato.
# Minute144.83---Customer47 arrives at the cafe.
# Minute145.75---Customer45 get the cappuccino and leave.
# Minute145.75---Customer47 starts to order.
# Minute146.84---Customer48 arrives at the cafe.
# Minute147.18---Customer47 order a Caramel Macchiato.
# Minute148.07---Customer46 get the Caramel Macchiato and leave.
# Minute148.07---Customer48 starts to order.
# Minute150.86---Customer48 order a latte.
# Minute151.18---Customer47 get the Caramel Macchiato and leave.
# Minute153.86---Customer48 get the latte and leave.
# Minute160.07---Customer49 arrives at the cafe.
# Minute160.07---Customer49 starts to order.
# Minute161.36---Customer49 order a mocha.
# Minute164.01---Customer50 arrives at the cafe.
# Minute164.01---Customer50 starts to order.
# Minute164.86---Customer49 get the mocha and leave.
# Minute165.12---Customer50 order a Caramel Macchiato.
# Minute165.71---Customer51 arrives at the cafe.
# Minute165.71---Customer51 starts to order.
# Minute166.83---Customer51 order a Caramel Macchiato.
# Minute167.50---Customer52 arrives at the cafe.
# Minute169.12---Customer50 get the Caramel Macchiato and leave.
# Minute169.12---Customer52 starts to order.
# Minute170.65---Customer53 arrives at the cafe.
# Minute170.83---Customer51 get the Caramel Macchiato and leave.
# Minute170.83---Customer53 starts to order.
# Minute171.78---Customer52 order a mocha.
# Minute172.63---Customer53 order a latte.
# Minute175.28---Customer52 get the mocha and leave.
# Minute175.63---Customer53 get the latte and leave.
# Minute177.87---Customer54 arrives at the cafe.
# Minute177.87---Customer54 starts to order.
# Minute179.70---Customer55 arrives at the cafe.
# Minute179.70---Customer55 starts to order.
# Minute180.14---Customer54 order a Caramel Macchiato.
# Minute180.80---Customer55 order a cappuccino.
# Minute181.41---Customer56 arrives at the cafe.
# Minute183.75---Customer57 arrives at the cafe.
# Minute183.80---Customer55 get the cappuccino and leave.
# Minute183.80---Customer56 starts to order.
# Minute184.14---Customer54 get the Caramel Macchiato and leave.
# Minute184.14---Customer57 starts to order.
# Minute185.67---Customer57 order a americano.
# Minute186.41---Customer56 order a cappuccino.
# Minute187.17---Customer57 get the americano and leave.
# Minute187.95---Customer58 arrives at the cafe.
# Minute187.95---Customer58 starts to order.
# Minute189.41---Customer56 get the cappuccino and leave.
# Minute190.14---Customer58 order a mocha.
# Minute192.47---Customer59 arrives at the cafe.
# Minute192.47---Customer59 starts to order.
# Minute192.73---Customer60 arrives at the cafe.
# Minute193.64---Customer58 get the mocha and leave.
# Minute193.64---Customer60 starts to order.
# Minute194.71---Customer60 order a Caramel Macchiato.
# Minute195.24---Customer59 order a cappuccino.
# Minute197.18---Customer61 arrives at the cafe.
# Minute198.24---Customer59 get the cappuccino and leave.
# Minute198.24---Customer61 starts to order.
# Minute198.71---Customer60 get the Caramel Macchiato and leave.
# Minute199.21---Customer62 arrives at the cafe.
# Minute199.21---Customer62 starts to order.
# Minute200.20---Customer61 order a latte.
# Minute201.12---Customer62 order a americano.
# Minute202.62---Customer62 get the americano and leave.
# Minute203.20---Customer61 get the latte and leave.
# Minute206.32---Customer63 arrives at the cafe.
# Minute206.32---Customer63 starts to order.
# Minute207.27---Customer64 arrives at the cafe.
# Minute207.27---Customer64 starts to order.
# Minute208.59---Customer63 order a Caramel Macchiato.
# Minute209.96---Customer64 order a latte.
# Minute212.59---Customer63 get the Caramel Macchiato and leave.
# Minute212.96---Customer64 get the latte and leave.
# Minute220.52---Customer65 arrives at the cafe.
# Minute220.52---Customer65 starts to order.
# Minute220.55---Customer66 arrives at the cafe.
# Minute220.55---Customer66 starts to order.
# Minute221.77---Customer66 order a americano.
# Minute222.13---Customer67 arrives at the cafe.
# Minute223.16---Customer65 order a americano.
# Minute223.27---Customer66 get the americano and leave.
# Minute223.27---Customer67 starts to order.
# Minute224.66---Customer65 get the americano and leave.
# Minute226.03---Customer67 order a cappuccino.
# Minute226.92---Customer68 arrives at the cafe.
# Minute226.92---Customer68 starts to order.
# Minute228.54---Customer68 order a mocha.
# Minute229.03---Customer67 get the cappuccino and leave.
# Minute230.19---Customer69 arrives at the cafe.
# Minute230.19---Customer69 starts to order.
# Minute230.58---Customer70 arrives at the cafe.
# Minute232.04---Customer68 get the mocha and leave.
# Minute232.04---Customer70 starts to order.
# Minute232.67---Customer69 order a mocha.
# Minute233.59---Customer70 order a americano.
# Minute234.25---Customer71 arrives at the cafe.
# Minute234.26---Customer72 arrives at the cafe.
# Minute234.97---Customer73 arrives at the cafe.
# Minute235.09---Customer70 get the americano and leave.
# Minute235.09---Customer71 starts to order.
# Minute236.17---Customer69 get the mocha and leave.
# Minute236.17---Customer72 starts to order.
# Minute236.30---Customer74 arrives at the cafe.
# Minute237.17---Customer71 order a americano.
# Minute237.55---Customer75 arrives at the cafe.
# Minute238.03---Customer72 order a americano.
# Minute238.67---Customer71 get the americano and leave.
# Minute238.67---Customer73 starts to order.
# Minute239.53---Customer72 get the americano and leave.
# Minute239.53---Customer74 starts to order.
# Minute240.30---Customer75 leaves the cafe after waiting for 2.8 minutes.
# Minute240.55---Customer74 order a americano.
# Minute240.58---Customer73 order a mocha.
# Minute242.05---Customer74 get the americano and leave.
# Minute244.08---Customer73 get the mocha and leave.
# Minute246.30---Customer76 arrives at the cafe.
# Minute246.30---Customer76 starts to order.
# Minute246.52---Customer77 arrives at the cafe.
# Minute246.52---Customer77 starts to order.
# Minute247.77---Customer77 order a americano.
# Minute249.27---Customer77 get the americano and leave.
# Minute249.29---Customer76 order a Caramel Macchiato.
# Minute250.57---Customer78 arrives at the cafe.
# Minute250.57---Customer78 starts to order.
# Minute252.21---Customer79 arrives at the cafe.
# Minute252.92---Customer78 order a mocha.
# Minute253.29---Customer76 get the Caramel Macchiato and leave.
# Minute253.29---Customer79 starts to order.
# Minute256.03---Customer79 order a cappuccino.
# Minute256.42---Customer78 get the mocha and leave.
# Minute257.15---Customer80 arrives at the cafe.
# Minute257.15---Customer80 starts to order.
# Minute259.03---Customer79 get the cappuccino and leave.
# Minute259.16---Customer81 arrives at the cafe.
# Minute259.16---Customer81 starts to order.
# Minute259.82---Customer80 order a latte.
# Minute260.65---Customer81 order a Caramel Macchiato.
# Minute262.69---Customer82 arrives at the cafe.
# Minute262.82---Customer80 get the latte and leave.
# Minute262.82---Customer82 starts to order.
# Minute264.02---Customer82 order a Caramel Macchiato.
# Minute264.65---Customer81 get the Caramel Macchiato and leave.
# Minute268.02---Customer82 get the Caramel Macchiato and leave.
# Minute270.35---Customer83 arrives at the cafe.
# Minute270.35---Customer83 starts to order.
# Minute272.46---Customer83 order a americano.
# Minute273.96---Customer83 get the americano and leave.
# Minute274.61---Customer84 arrives at the cafe.
# Minute274.61---Customer84 starts to order.
# Minute276.07---Customer84 order a cappuccino.
# Minute279.07---Customer84 get the cappuccino and leave.
# Minute284.82---Customer85 arrives at the cafe.
# Minute284.82---Customer85 starts to order.
# Minute286.72---Customer85 order a americano.
# Minute288.22---Customer85 get the americano and leave.
# Minute288.98---Customer86 arrives at the cafe.
# Minute288.98---Customer86 starts to order.
# Minute291.18---Customer86 order a mocha.
# Minute291.84---Customer87 arrives at the cafe.
# Minute291.84---Customer87 starts to order.
# Minute294.27---Customer87 order a americano.
# Minute294.48---Customer88 arrives at the cafe.
# Minute294.68---Customer86 get the mocha and leave.
# Minute294.68---Customer88 starts to order.
# Minute295.77---Customer87 get the americano and leave.
# Minute296.03---Customer89 arrives at the cafe.
# Minute296.03---Customer89 starts to order.
# Minute296.14---Customer88 order a mocha.
# Minute297.24---Customer89 order a Caramel Macchiato.
# Minute299.64---Customer88 get the mocha and leave.
# Minute300.33---Customer90 arrives at the cafe.
# Minute300.33---Customer90 starts to order.
# Minute301.24---Customer89 get the Caramel Macchiato and leave.
# Minute302.30---Customer90 order a Caramel Macchiato.
# Minute306.30---Customer90 get the Caramel Macchiato and leave.
# Minute308.29---Customer91 arrives at the cafe.
# Minute308.29---Customer91 starts to order.
# Minute310.03---Customer91 order a latte.
# Minute310.09---Customer92 arrives at the cafe.
# Minute310.09---Customer92 starts to order.
# Minute312.66---Customer92 order a mocha.
# Minute313.03---Customer91 get the latte and leave.
# Minute315.09---Customer93 arrives at the cafe.
# Minute315.09---Customer93 starts to order.
# Minute316.16---Customer92 get the mocha and leave.
# Minute316.89---Customer93 order a cappuccino.
# Minute319.57---Customer94 arrives at the cafe.
# Minute319.57---Customer94 starts to order.
# Minute319.89---Customer93 get the cappuccino and leave.
# Minute321.22---Customer95 arrives at the cafe.
# Minute321.22---Customer95 starts to order.
# Minute321.85---Customer94 order a mocha.
# Minute321.90---Customer96 arrives at the cafe.
# Minute322.43---Customer97 arrives at the cafe.
# Minute324.01---Customer95 order a americano.
# Minute324.11---Customer96 leaves the cafe after waiting for 2.2 minutes.
# Minute325.35---Customer94 get the mocha and leave.
# Minute325.35---Customer97 starts to order.
# Minute325.51---Customer95 get the americano and leave.
# Minute326.13---Customer98 arrives at the cafe.
# Minute326.13---Customer98 starts to order.
# Minute326.31---Customer99 arrives at the cafe.
# Minute327.74---Customer98 order a americano.
# Minute327.91---Customer97 order a Caramel Macchiato.
# Minute328.72---Customer99 leaves the cafe after waiting for 2.4 minutes.
# Minute329.24---Customer98 get the americano and leave.
# Minute331.91---Customer97 get the Caramel Macchiato and leave.

# %% [markdown]
# This programme simulate a cafe with 2 counters.
# Customers come in random time interval and stand in line for a cup of coffee.But if the waiting time is longer than the customer can tolerate, the customer leave.
# If the customer does not leave,he/she will order, wait for the coffe to be made and leave.
# From the simulation we can see if there are only one counter, there will be many customer leave after waiting a long time. 2 counters can slove this problem effectively.
